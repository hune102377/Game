# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./data/data.csv')

# %%
data = data.drop(['Rank', 'Name'], axis=1)

# %%
a_list = list(data.isnull().sum())
a_list.append(len(data))
a_list
# Out:
# [0, 271, 0, 58, 0, 0, 0, 0, 0, 0, 16598]

# %%
b_list = list(data.isnull().sum().index)
b_list.append('Total')
b_list
# Out:
# ['Platform',
#  'Year',
#  'Genre',
#  'Publisher',
#  'NA_Sales',
#  'EU_Sales',
#  'JP_Sales',
#  'Other_Sales',
#  'Global_Sales',
#  'Region',
#  'Total']

# %%
plt.figure(figsize = (8,6))

plt.barh(b_list, a_list,  color = 'tomato')
plt.title('Show Missing Value')
plt.show()

# %%
data = data.dropna()

# %%
a_list = list(data['Platform'].value_counts())

# %%
plt.figure(figsize = (8,6))
plt.barh(data['Platform'].value_counts(ascending=True).index, data['Platform'].value_counts(ascending=True), color = 'tomato')
plt.title('Game Platform')
plt.show()

# %%
data['Year'] = data['Year'].astype(int).astype(str)

# %%
import datetime as dt

# %%
data['Year'] = pd.to_datetime(data['Year'],format='%Y')

# %%
data = data.reset_index(drop=True)
data
# Out:
#       Platform       Year         Genre   Publisher  NA_Sales  EU_Sales  \
# 0          Wii 2006-01-01        Sports    Nintendo     41.49     29.02
# 1          NES 1985-01-01      Platform    Nintendo     29.08      3.58
# 2          Wii 2008-01-01        Racing    Nintendo     15.85     12.88
# 3          Wii 2009-01-01        Sports    Nintendo     15.75     11.01
# 4           GB 1996-01-01  Role-Playing    Nintendo     11.27      8.89
# ...        ...        ...           ...         ...       ...       ...
# 16286      GBA 2002-01-01      Platform       Kemco      0.01      0.00
# 16287       GC 2003-01-01       Shooter  Infogrames      0.01      0.00
# 16288      PS2 2008-01-01        Racing  Activision      0.00      0.00
# 16289       DS 2010-01-01        Puzzle    7G//AMES      0.00      0.01
# 16290      GBA 2003-01-01      Platform     Wanadoo      0.01      0.00
#
#        JP_Sales  Other_Sales  Global_Sales  Region
# 0          3.77         8.46         82.74       0
# ...

# %%
for i in range(0,len(data)) :
    try :
        data['Year'][i] = data['Year'][i].year
    except :
        continue
# Out:
# C:\Users\hermit\AppData\Local\Temp\ipykernel_5240\3931449778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Year'][i] = data['Year'][i].year

# %%
data

# %%
data['Year'].value_counts()
# Out:
# 2009    1431
# 2008    1428
# 2010    1257
# 2007    1201
# 2011    1136
# 2006    1008
# 2005     936
# 2002     829
# 2003     775
# 2004     744
# 2012     655
# 2015     614
# 2014     580
# 2013     546
# 2001     482
# 1998     379
# 2000     349
# 2016     342
# 1999     338
# 1997     289
# 1996     263
# 1995     219
# 1994     121
# 1993      60
# 1981      46
# 1992      43
# 1991      41
# 1982      36
# 1986      21
# 1989      17
# 1983      17
# 1990      16
# 1987      16
# 1988      15
# 1985      14
# 1984      14
# 1980       9
# 2017       3
# 2020       1
# Name: Year, dtype: int64

# %%
plt.figure(figsize = (8,6))
plt.bar(data['Year'].value_counts().index, data['Year'].value_counts(), color = 'tomato')
plt.title('Game Year')
plt.show()

# %%
data['Genre'].value_counts()
# Out:
# Action          3251
# Sports          2304
# Misc            1686
# Role-Playing    1470
# Shooter         1282
# Adventure       1274
# Racing          1225
# Platform         875
# Simulation       848
# Fighting         836
# Strategy         670
# Puzzle           570
# Name: Genre, dtype: int64

# %%
plt.figure(figsize = (8,6))
plt.barh(data['Genre'].value_counts(ascending=True).index, data['Genre'].value_counts(ascending=True), color = 'tomato')
plt.title('Game Genre')
plt.show()

# %%
t = list(data['Publisher'].value_counts())

# %%
from collections import Counter

# %%
result = Counter(t)
print(result)
# Out:
# Counter({1: 192, 2: 67, 3: 56, 4: 28, 6: 22, 5: 22, 8: 16, 7: 12, 14: 10, 10: 9, 9: 9, 16: 8, 13: 8, 17: 6, 12: 6, 18: 5, 15: 5, 22: 4, 19: 4, 37: 3, 32: 3, 30: 3, 27: 3, 26: 3, 23: 3, 11: 3, 196: 2, 104: 2, 61: 2, 56: 2, 45: 2, 39: 2, 36: 2, 35: 2, 25: 2, 21: 2, 20: 2, 1339: 1, 966: 1, 928: 1, 918: 1, 823: 1, 712: 1, 696: 1, 682: 1, 632: 1, 412: 1, 376: 1, 347: 1, 338: 1, 231: 1, 217: 1, 214: 1, 192: 1, 189: 1, 184: 1, 183: 1, 161: 1, 150: 1, 128: 1, 121: 1, 100: 1, 90: 1, 89: 1, 85: 1, 81: 1, 73: 1, 71: 1, 69: 1, 67: 1, 62: 1, 59: 1, 52: 1, 51: 1, 50: 1, 44: 1, 43: 1, 40: 1, 33: 1, 29: 1, 24: 1})

# %%
t.count(1), t.count(2),  t.count(3)
# Out:
# (192, 67, 56)

# %%
data['Publisher'].value_counts(ascending=False)
# Out:
# Electronic Arts                 1339
# Activision                       966
# Namco Bandai Games               928
# Ubisoft                          918
# Konami Digital Entertainment     823
#                                 ...
# Detn8 Games                        1
# Pow                                1
# Navarre Corp                       1
# MediaQuest                         1
# UIG Entertainment                  1
# Name: Publisher, Length: 576, dtype: int64

# %%
list_2 = []
for i in range(0,len(data['Publisher'].value_counts(ascending=True).index)) :
    list_2.append(i)

# %%
plt.bar(list_2, data['Publisher'].value_counts(ascending=False), color = 'tomato')
plt.title('Game Publisher')
plt.show()

# %%
data['Year'].astype(dat)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16291 entries, 0 to 16290
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Platform      16291 non-null  object
#  1   Year          16291 non-null  object
#  2   Genre         16291 non-null  object
#  3   Publisher     16291 non-null  object
#  4   NA_Sales      16291 non-null  float64
#  5   EU_Sales      16291 non-null  float64
#  6   JP_Sales      16291 non-null  float64
#  7   Other_Sales   16291 non-null  float64
#  8   Global_Sales  16291 non-null  float64
#  9   Region        16291 non-null  int64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 1.2+ MB

# %%
data.to_csv('./data/data_01.csv', index=False)
